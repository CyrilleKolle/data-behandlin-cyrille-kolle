# %% [markdown]
# ## 1 Cities in Sweden

# %%
import pandas as pd

kommun = pd.Series({0: "Malmö", 1:"Stockholm", 2:"Uppsala", 3:"Göteborg"})
population = pd.Series({0: 347949, 1:975551, 2:233839, 3:583056})

df_cities = pd.DataFrame({"Kommun":kommun, "Population":population})
df_cities
# Out:
#       Kommun  Population
# 0      Malmö      347949
# 1  Stockholm      975551
# 2    Uppsala      233839
# 3   Göteborg      583056

# %%
df_cities["Kommun"]
# Out:
# 0        Malmö
# 1    Stockholm
# 2      Uppsala
# 3     Göteborg
# Name: Kommun, dtype: object

# %%
df_göteborg = df_cities[df_cities["Kommun"] == "Göteborg"]
df_göteborg
# Out:
#      Kommun  Population
# 3  Göteborg      583056

# %%
df_sorted_cities = df_cities.sort_values(by="Population", ascending=False)
df_sorted_cities
# Out:
#       Kommun  Population
# 1  Stockholm      975551
# 3   Göteborg      583056
# 0      Malmö      347949
# 2    Uppsala      233839

# %%
top3_largest_cities = df_sorted_cities[:3]
top3_largest_cities
# Out:
#       Kommun  Population
# 1  Stockholm      975551
# 3   Göteborg      583056
# 0      Malmö      347949

# %%
total_pop =  10379295
df_cities.assign(Percentage=lambda x: (x.Population/total_pop)*100)
# Out:
#       Kommun  Population  Percentage
# 0      Malmö      347949    3.352338
# 1  Stockholm      975551    9.399010
# 2    Uppsala      233839    2.252937
# 3   Göteborg      583056    5.617491

# %% [markdown]
# ## Exercises 2 and 3

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_excel("../Data/komtopp50_2020.xlsx")


df.columns = ["RanK2020", "RanK2019", "Kommun", "Population2020", "Population2019", "change"]

df.head()

#df.sort_values(by="Kommun", ascending=True).reset_index().head()
# Out:
#                                         RanK2020  RanK2019  Kommun  \
# 0                                            NaN       NaN     NaN
# 1  Sveriges 50 största kommuner efter folkmängd,       NaN     NaN
# 2  31 december 2020 jämfört med 31 december 2019       NaN     NaN
# 3                                            NaN       NaN     NaN
# 4                                           Rang       NaN  Kommun
#
#           Population2020  Population2019      change
# 0                    NaN             NaN         NaN
# 1                    NaN             NaN         NaN
# 2                    NaN             NaN         NaN
# 3                    NaN             NaN         NaN
# 4  Folkmängd 31 december             NaN  Förändring

# %%
df_Gothenburg = df[df["Kommun"] == "Göteborg"]
df_Gothenburg
# Out:
#   RanK2020  RanK2019    Kommun Population2020  Population2019 change
# 7        2       2.0  Göteborg         583056        579281.0   3775

# %%
df.sort_values(by="Population2019", ascending=True).head()
# Out:
#    RanK2020  RanK2019      Kommun Population2020  Population2019 change
# 5      2020    2019.0         NaN           2020          2019.0    NaN
# 55       50      50.0      Tyresö          48678         48333.0    345
# 54       49      49.0     Sigtuna          49537         48964.0    573
# 53       48      48.0  Hässleholm          52010         52145.0   -135
# 51       46      47.0  Sundbyberg          52801         52414.0    387

# %%
df.sort_values(by="Population2019", ascending=False).head()
# Out:
#    RanK2020  RanK2019     Kommun Population2020  Population2019 change
# 6         1       1.0  Stockholm         975551        974073.0   1478
# 7         2       2.0   Göteborg         583056        579281.0   3775
# 8         3       3.0      Malmö         347949        344166.0   3783
# 9         4       4.0    Uppsala         233839        230767.0   3072
# 10        5       5.0  Linköping         164616        163051.0   1565

# %%
top3_largest_populations = df.sort_values(by="Population2019", ascending=False).head()[:3]
top3_largest_populations
# Out:
#   RanK2020  RanK2019     Kommun Population2020  Population2019 change
# 6        1       1.0  Stockholm         975551        974073.0   1478
# 7        2       2.0   Göteborg         583056        579281.0   3775
# 8        3       3.0      Malmö         347949        344166.0   3783

# %%
total_pop = 10379295
df["Pop_Percentage"]=(df["Population2019"]/ total_pop) *100

df.tail()
# Out:
#    RanK2020  RanK2019      Kommun Population2020  Population2019 change  \
# 51       46      47.0  Sundbyberg          52801         52414.0    387
# 52       47      46.0    Borlänge          52394         52590.0   -196
# 53       48      48.0  Hässleholm          52010         52145.0   -135
# 54       49      49.0     Sigtuna          49537         48964.0    573
# 55       50      50.0      Tyresö          48678         48333.0    345
#
#     Pop_Percentage
# 51        0.504986
# 52        0.506682
# 53        0.502394
# 54        0.471747
# 55        0.465667

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

#df = pd.read_excel("../Data/komtopp50_2020.xlsx")

xls = pd.ExcelFile("../Data/komtopp50_2020.xlsx")
#df.columns = ["RanK2020", "RanK2019", "Kommun", "Population2020", "Population2019", "change"]
df_totalt = pd.read_excel(xls, 'Totalt')

df_totalt = df_totalt.iloc[6:]
#df = df.iloc[6:]
df_totalt.head()
df_totalt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290 entries, 6 to 295
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  290 non-null    object
#  1   Unnamed: 1  290 non-null    float64
#  2   Unnamed: 2  290 non-null    object
#  3   Unnamed: 3  290 non-null    object
#  4   Unnamed: 4  290 non-null    float64
#  5   Unnamed: 5  290 non-null    object
# dtypes: float64(2), object(4)
# memory usage: 13.7+ KB

# %%
df_totalt.describe()
# Out:
#        Unnamed: 1     Unnamed: 4
# count  290.000000     290.000000
# mean   145.496552   35612.375862
# std     83.856743   74292.525065
# min      1.000000    2408.000000
# 25%     73.250000   10075.000000
# 50%    145.500000   15978.000000
# 75%    217.750000   36096.750000
# max    290.000000  974073.000000

# %%
df_totalt.shape
# Out:
# (290, 6)

# %%
#b
df_totalt.columns = ["RanK2020", "RanK2019", "Kommun", "Population2020", "Population2019", "change"]


total_sorted_kommun = df_totalt.sort_values(by="Population2019", ascending=False).head()
total_sorted_kommun
# Out:
#     RanK2020  RanK2019     Kommun Population2020  Population2019    change
# 204        1       1.0  Stockholm         975551        974073.0  0.151734
# 63         2       2.0   Göteborg         583056        579281.0   0.65167
# 140        3       3.0      Malmö         347949        344166.0  1.099179
# 247        4       4.0    Uppsala         233839        230767.0  1.331213
# 130        5       5.0  Linköping         164616        163051.0  0.959822

# %%
top_5_kommun = total_sorted_kommun[:5] 
print(top_5_kommun)
# Out:
#     RanK2020  RanK2019     Kommun Population2020  Population2019    change
# 204        1       1.0  Stockholm         975551        974073.0  0.151734
# 63         2       2.0   Göteborg         583056        579281.0   0.65167
# 140        3       3.0      Malmö         347949        344166.0  1.099179
# 247        4       4.0    Uppsala         233839        230767.0  1.331213
# 130        5       5.0  Linköping         164616        163051.0  0.959822

# %%
#c sort
sorted_kommun = df_totalt.sort_values(by="Population2020", ascending=True).reset_index(drop = True)

bottom5_cities = sorted_kommun[:5]
bottom5_cities
# Out:
#   RanK2020  RanK2019    Kommun Population2020  Population2019    change
# 0      290     290.0  Bjurholm           2387          2408.0 -0.872093
# 1      289     289.0   Sorsele           2442          2489.0 -1.888309
# 2      288     288.0   Dorotea           2498          2551.0 -2.077617
# 3      287     287.0  Arjeplog           2718          2785.0 -2.405745
# 4      286     286.0     Åsele           2805          2794.0  0.393701

# %%
pop_2019 = df_totalt["Population2019"].sum()
print(f"{pop_2019=}")
# Out:
# pop_2019=10327589.0

# %%
pop_2020 = df_totalt["Population2020"].sum()
print(f"{pop_2020=}")
# Out:
# pop_2020=10379295

# %%
#f plot graph
import seaborn as sns
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1,2, figsize=(16,4), dpi=120)
titles = ["Top 5 largest cities", "Top 5 smallest cities"]
data_frames = (top_5_kommun, bottom5_cities) 
x_colums = ["Kommun", "Kommun"]

for i, (data, title) in enumerate(zip(data_frames, titles)):
    sns.barplot(data=data, x=x_colums[i], y="Population2020", ax=axes[i])
    axes[i].set(title=title)

# %% [markdown]
# ## 3 Gender

# %%
df_men = pd.read_excel(xls, 'Män')


df_men.columns = ["RanK2020", "RanK2019", "Kommun", "Population2020", "Population2019", "change"]
df_men = df_men.iloc[6:].reset_index(drop = True)
df_men["Gender"] = "Man"
df_men.head()
# Out:
#   RanK2020  RanK2019    Kommun Population2020  Population2019    change Gender
# 0       81      83.0       Ale          16256         16054.0  1.258253    Man
# 1       64      64.0  Alingsås          20702         20646.0  0.271239    Man
# 2      122     123.0   Alvesta          10367         10339.0  0.270819    Man
# 3      255     255.0     Aneby           3503          3498.0  0.142939    Man
# 4      169     168.0    Arboga           7094          7114.0 -0.281136    Man

# %%
df_women = pd.read_excel(xls, 'Kvinnor')

df_women.columns = ["RanK2020", "RanK2019", "Kommun", "Population2020", "Population2019", "change"]
df_women = df_women[6:].reset_index(drop = True)
df_women["Gender"] = "Woman"

df_women.head()
# Out:
#   RanK2020  RanK2019    Kommun Population2020  Population2019    change Gender
# 0       84      85.0       Ale          15612         15348.0  1.720094  Woman
# 1       64      64.0  Alingsås          20900         20774.0  0.606527  Woman
# 2      123     123.0   Alvesta           9857          9795.0  0.632976  Woman
# 3      255     255.0     Aneby           3318          3350.0 -0.955224  Woman
# 4      165     164.0    Arboga           6945          6973.0 -0.401549  Woman

# %%
df_men.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290 entries, 0 to 289
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   RanK2020        290 non-null    object
#  1   RanK2019        290 non-null    float64
#  2   Kommun          290 non-null    object
#  3   Population2020  290 non-null    object
#  4   Population2019  290 non-null    float64
#  5   change          290 non-null    object
#  6   Gender          290 non-null    object
# dtypes: float64(2), object(5)
# memory usage: 16.0+ KB

# %%
df_women.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290 entries, 0 to 289
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   RanK2020        290 non-null    object
#  1   RanK2019        290 non-null    float64
#  2   Kommun          290 non-null    object
#  3   Population2020  290 non-null    object
#  4   Population2019  290 non-null    float64
#  5   change          290 non-null    object
#  6   Gender          290 non-null    object
# dtypes: float64(2), object(5)
# memory usage: 16.0+ KB

# %%
merged_men_women = pd.concat([df_men, df_women], axis=0)
merged_men_women.set_index("Kommun")
# Out:
#              RanK2020  RanK2019 Population2020  Population2019    change  \
# Kommun
# Ale                81      83.0          16256         16054.0  1.258253
# Alingsås           64      64.0          20702         20646.0  0.271239
# Alvesta           122     123.0          10367         10339.0  0.270819
# Aneby             255     255.0           3503          3498.0  0.142939
# Arboga            169     168.0           7094          7114.0 -0.281136
# ...               ...       ...            ...             ...       ...
# Österåker          55      57.0          22997         22442.0  2.473042
# Östhammar         117     118.0          10846         10803.0  0.398038
# Östra Göinge      160     159.0           7270          7262.0  0.110162
# Överkalix         284     284.0           1559          1578.0 -1.204056
# Övertorneå        279     279.0           2027          2065.0 -1.840194
#
#              Gender
# Kommun
# Ale             Man
# Alingsås        Man
# ...

# %%
del merged_men_women['RanK2019']

# %%
merged_men_women
# Out:
#     RanK2020        Kommun Population2020  Population2019    change Gender
# 0         81           Ale          16256         16054.0  1.258253    Man
# 1         64      Alingsås          20702         20646.0  0.271239    Man
# 2        122       Alvesta          10367         10339.0  0.270819    Man
# 3        255         Aneby           3503          3498.0  0.142939    Man
# 4        169        Arboga           7094          7114.0 -0.281136    Man
# ..       ...           ...            ...             ...       ...    ...
# 285       55     Österåker          22997         22442.0  2.473042  Woman
# 286      117     Östhammar          10846         10803.0  0.398038  Woman
# 287      160  Östra Göinge           7270          7262.0  0.110162  Woman
# 288      284     Överkalix           1559          1578.0 -1.204056  Woman
# 289      279    Övertorneå           2027          2065.0 -1.840194  Woman
#
# [580 rows x 6 columns]

# %%
del merged_men_women['RanK2020']

# %%
merged_men_women
# Out:
#            Kommun Population2020  Population2019    change Gender
# 0             Ale          16256         16054.0  1.258253    Man
# 1        Alingsås          20702         20646.0  0.271239    Man
# 2         Alvesta          10367         10339.0  0.270819    Man
# 3           Aneby           3503          3498.0  0.142939    Man
# 4          Arboga           7094          7114.0 -0.281136    Man
# ..            ...            ...             ...       ...    ...
# 285     Österåker          22997         22442.0  2.473042  Woman
# 286     Östhammar          10846         10803.0  0.398038  Woman
# 287  Östra Göinge           7270          7262.0  0.110162  Woman
# 288     Överkalix           1559          1578.0 -1.204056  Woman
# 289    Övertorneå           2027          2065.0 -1.840194  Woman
#
# [580 rows x 5 columns]

# %%
df_totalt
# Out:
#     RanK2020  RanK2019        Kommun Population2020  Population2019    change
# 6         83      84.0           Ale          31868         31402.0  1.483982
# 7         64      64.0      Alingsås          41602         41420.0  0.439401
# 8        123     123.0       Alvesta          20224         20134.0  0.447005
# 9        255     255.0         Aneby           6821          6848.0 -0.394276
# 10       169     167.0        Arboga          14039         14087.0  -0.34074
# ..       ...       ...           ...            ...             ...       ...
# 291       54      55.0     Österåker          46644         45574.0   2.34783
# 292      116     115.0     Östhammar          22251         22250.0  0.004494
# 293      160     159.0  Östra Göinge          15017         15007.0  0.066636
# 294      284     284.0     Överkalix           3289          3315.0 -0.784314
# 295      279     279.0    Övertorneå           4217          4299.0  -1.90742
#
# [290 rows x 6 columns]

# %%
del df_totalt['RanK2020']
del df_totalt['RanK2019']

# %%
df_totalt
# Out:
#            Kommun Population2020  Population2019    change
# 6             Ale          31868         31402.0  1.483982
# 7        Alingsås          41602         41420.0  0.439401
# 8         Alvesta          20224         20134.0  0.447005
# 9           Aneby           6821          6848.0 -0.394276
# 10         Arboga          14039         14087.0  -0.34074
# ..            ...            ...             ...       ...
# 291     Österåker          46644         45574.0   2.34783
# 292     Östhammar          22251         22250.0  0.004494
# 293  Östra Göinge          15017         15007.0  0.066636
# 294     Överkalix           3289          3315.0 -0.784314
# 295    Övertorneå           4217          4299.0  -1.90742
#
# [290 rows x 4 columns]

# %%
df_totalt = df_totalt.rename(
    dict(Population2020="TotalPop2020", Population2019="TotalPop2019", change="TotalChange"),
    axis="columns",
).reset_index(drop = True)

# %%
df_totalt
# Out:
#            Kommun TotalPop2020  TotalPop2019 TotalChange
# 0             Ale        31868       31402.0    1.483982
# 1        Alingsås        41602       41420.0    0.439401
# 2         Alvesta        20224       20134.0    0.447005
# 3           Aneby         6821        6848.0   -0.394276
# 4          Arboga        14039       14087.0    -0.34074
# ..            ...          ...           ...         ...
# 285     Österåker        46644       45574.0     2.34783
# 286     Östhammar        22251       22250.0    0.004494
# 287  Östra Göinge        15017       15007.0    0.066636
# 288     Överkalix         3289        3315.0   -0.784314
# 289    Övertorneå         4217        4299.0    -1.90742
#
# [290 rows x 4 columns]

# %%
sorted = merged_men_women.sort_values(by="Kommun", ascending=False, inplace=True)

# %%
sorted

# %%
df_totalt
# Out:
#            Kommun TotalPop2020  TotalPop2019 TotalChange
# 0             Ale        31868       31402.0    1.483982
# 1        Alingsås        41602       41420.0    0.439401
# 2         Alvesta        20224       20134.0    0.447005
# 3           Aneby         6821        6848.0   -0.394276
# 4          Arboga        14039       14087.0    -0.34074
# ..            ...          ...           ...         ...
# 285     Österåker        46644       45574.0     2.34783
# 286     Östhammar        22251       22250.0    0.004494
# 287  Östra Göinge        15017       15007.0    0.066636
# 288     Överkalix         3289        3315.0   -0.784314
# 289    Övertorneå         4217        4299.0    -1.90742
#
# [290 rows x 4 columns]

# %%
merged_men_women.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 580 entries, 289 to 0
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Kommun          580 non-null    object
#  1   Population2020  580 non-null    object
#  2   Population2019  580 non-null    float64
#  3   change          580 non-null    object
#  4   Gender          580 non-null    object
# dtypes: float64(1), object(4)
# memory usage: 27.2+ KB

# %%
df_totalt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290 entries, 0 to 289
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Kommun        290 non-null    object
#  1   TotalPop2020  290 non-null    object
#  2   TotalPop2019  290 non-null    float64
#  3   TotalChange   290 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 9.2+ KB

# %%
a = merged_men_women.sort_values("Kommun", ascending=True)

# %%
a
# Out:
#            Kommun Population2020  Population2019    change Gender
# 0             Ale          15612         15348.0  1.720094  Woman
# 0             Ale          16256         16054.0  1.258253    Man
# 1        Alingsås          20900         20774.0  0.606527  Woman
# 1        Alingsås          20702         20646.0  0.271239    Man
# 2         Alvesta          10367         10339.0  0.270819    Man
# ..            ...            ...             ...       ...    ...
# 287  Östra Göinge           7747          7745.0  0.025823    Man
# 288     Överkalix           1559          1578.0 -1.204056  Woman
# 288     Överkalix           1730          1737.0 -0.402994    Man
# 289    Övertorneå           2190          2234.0 -1.969561    Man
# 289    Övertorneå           2027          2065.0 -1.840194  Woman
#
# [580 rows x 5 columns]

# %% [markdown]
# ## d

# %%
t = a.join(df_totalt.set_index("Kommun"), on="Kommun")

# %%
t.sort_values(by="Population2019", ascending=False).head()
# Out:
#         Kommun Population2020  Population2019    change Gender TotalPop2020  \
# 198  Stockholm         492569        491853.0  0.145572  Woman       975551
# 198  Stockholm         482982        482220.0  0.158019    Man       975551
# 57    Göteborg         292505        290308.0  0.756782    Man       583056
# 57    Göteborg         290551        288973.0  0.546072  Woman       583056
# 134      Malmö         175411        173543.0   1.07639  Woman       347949
#
#      TotalPop2019 TotalChange
# 198      974073.0    0.151734
# 198      974073.0    0.151734
# 57       579281.0     0.65167
# 57       579281.0     0.65167
# 134      344166.0    1.099179

# %% [markdown]
# ## e

# %%
import seaborn as sns

s = merged_men_women.sort_values(by="Population2019", ascending=False)

# %%
s["Kommun"].unique()
# Out:
# array(['Stockholm', 'Göteborg', 'Malmö', 'Uppsala', 'Linköping', 'Örebro',
#        'Västerås', 'Helsingborg', 'Norrköping', 'Jönköping', 'Umeå',
#        'Lund', 'Huddinge', 'Borås', 'Eskilstuna', 'Nacka', 'Halmstad',
#        'Gävle', 'Södertälje', 'Sundsvall', 'Botkyrka', 'Växjö',
#        'Karlstad', 'Haninge', 'Kristianstad', 'Kungsbacka', 'Solna',
#        'Järfälla', 'Luleå', 'Sollentuna', 'Skellefteå', 'Täby', 'Mölndal',
#        'Kalmar', 'Karlskrona', 'Varberg', 'Östersund', 'Norrtälje',
#        'Falun', 'Gotland', 'Trollhättan', 'Skövde', 'Nyköping',
#        'Uddevalla', 'Örnsköldsvik', 'Borlänge', 'Sundbyberg',
#        'Hässleholm', 'Sigtuna', 'Lidingö', 'Tyresö', 'Upplands Väsby',
#        'Landskrona', 'Kungälv', 'Österåker', 'Enköping', 'Falkenberg',
#        'Trelleborg', 'Värmdö', 'Motala', 'Ängelholm', 'Lerum', 'Piteå',
#        'Alingsås', 'Lidköping', 'Vänersborg', 'Sandviken', 'Partille',
#        'Härryda', 'Hudiksvall', 'Vellinge', 'Strängnäs', 'Västervik',
# ...

# %%
top10 = s.head(20 )
top10
# Out:
#           Kommun Population2020  Population2019    change Gender
# 198    Stockholm         492569        491853.0  0.145572  Woman
# 198    Stockholm         482982        482220.0  0.158019    Man
# 57      Göteborg         292505        290308.0  0.756782    Man
# 57      Göteborg         290551        288973.0  0.546072  Woman
# 134        Malmö         175411        173543.0   1.07639  Woman
# 134        Malmö         172538        170623.0  1.122357    Man
# 241      Uppsala         118147        116434.0   1.47122  Woman
# 241      Uppsala         115692        114333.0  1.188633    Man
# 124    Linköping          84055         83183.0  1.048291    Man
# 124    Linköping          80561         79868.0  0.867682  Woman
# 281       Örebro          78785         78468.0  0.403986  Woman
# 263     Västerås          78107         77311.0  1.029608    Man
# 281       Örebro          77596         77228.0  0.476511    Man
# ...

# %%
bottom10 = s.tail(20)
bottom10
# Out:
#         Kommun Population2020  Population2019    change Gender
# 265       Ydre           1936          1934.0  0.103413    Man
# 157     Norsjö           1909          1918.0 -0.469239  Woman
# 199   Storfors           1892          1906.0 -0.734523  Woman
# 146   Munkfors           1880          1887.0 -0.370959    Man
# 146   Munkfors           1845          1853.0 -0.431732  Woman
# 265       Ydre           1790          1813.0 -1.268616  Woman
# 288  Överkalix           1730          1737.0 -0.402994    Man
# 136       Malå           1555          1586.0 -1.954603    Man
# 288  Överkalix           1559          1578.0 -1.204056  Woman
# 136       Malå           1469          1482.0 -0.877193  Woman
# 5     Arjeplog           1426          1458.0 -2.194787    Man
# 271      Åsele           1469          1456.0  0.892857    Man
# 29     Dorotea           1327          1356.0 -2.138643    Man
# 271      Åsele           1336          1338.0 -0.149477  Woman
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1,2, figsize=(16, 4), dpi=120)
titles = ["Top 10 gender pop", "Bottom 10 gender pop"]
data_frames = (top10, bottom10)
x_colums = ["Population2019", "Population2020"]

for i, (data, title) in enumerate(zip(data_frames, titles)):
    sns.barplot(data=data, x=x_colums[i], y="Kommun", ax=axes[i], hue="Gender")
    axes[i].set(title=title)
fig.show()
# Out:
# C:\Users\CYRILLE\AppData\Local\Temp\ipykernel_33252\2155910195.py:12: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## f

# %%
total_women_pop_2020 = df_women["Population2020"].sum()

# %%
total_men_pop_2020 = df_men["Population2020"].sum()

# %%
data = (total_women_pop_2020, total_men_pop_2020)
keys = ("Total women population", "Total men population")
palette_color = sns.color_palette("bright")


plt.pie(data, labels=keys, colors=palette_color, autopct='%2.1f%%', shadow=True, startangle=90)
plt.show()

# %%
merged_men_women
# Out:
#            Kommun Population2020  Population2019    change Gender
# 289    Övertorneå           2027          2065.0 -1.840194  Woman
# 289    Övertorneå           2190          2234.0 -1.969561    Man
# 288     Överkalix           1730          1737.0 -0.402994    Man
# 288     Överkalix           1559          1578.0 -1.204056  Woman
# 287  Östra Göinge           7747          7745.0  0.025823    Man
# ..            ...            ...             ...       ...    ...
# 2         Alvesta           9857          9795.0  0.632976  Woman
# 1        Alingsås          20900         20774.0  0.606527  Woman
# 1        Alingsås          20702         20646.0  0.271239    Man
# 0             Ale          16256         16054.0  1.258253    Man
# 0             Ale          15612         15348.0  1.720094  Woman
#
# [580 rows x 5 columns]

# %%
#df["Calories"] =df["Calories"].str[:-3].astype(int)
pp = merged_men_women["change"].str.replace('.', '').astype(float)
pp
# Out:
# C:\Users\CYRILLE\AppData\Local\Temp\ipykernel_33252\3529141901.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   pp = merged_men_women["change"].str.replace('.', '').join().astype(float)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [700], line 2
#       1 #df["Calories"] =df["Calories"].str[:-3].astype(int)
# ----> 2 pp = merged_men_women["change"].str.replace('.', '').join().astype(float)
#       3 pp
#
# File c:\Users\CYRILLE\.virtualenvs\data-behandlin-cyrille-kolle-IH-hno8Y\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
# ...

# %%
pp = merged_men_women.sort_values(by="change", ascending=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [670], line 1
# ----> 1 pp = merged_men_women.sort_values(by="change", ascending=False)
#
# File c:\Users\CYRILLE\.virtualenvs\data-behandlin-cyrille-kolle-IH-hno8Y\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\CYRILLE\.virtualenvs\data-behandlin-cyrille-kolle-IH-hno8Y\lib\site-packages\pandas\core\frame.py:6912, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
# ...

# %%
top5 = pp.head(10)
top5
# Out:
#         Kommun Population2020  Population2019    change Gender
# 198  Stockholm         492569        491853.0  0.145572  Woman
# 198  Stockholm         482982        482220.0  0.158019    Man
# 57    Göteborg         292505        290308.0  0.756782    Man
# 57    Göteborg         290551        288973.0  0.546072  Woman
# 134      Malmö         175411        173543.0   1.07639  Woman
# 134      Malmö         172538        170623.0  1.122357    Man
# 241    Uppsala         118147        116434.0   1.47122  Woman
# 241    Uppsala         115692        114333.0  1.188633    Man
# 124  Linköping          84055         83183.0  1.048291    Man
# 124  Linköping          80561         79868.0  0.867682  Woman

# %%
bottom5 = pp.tail(10)
bottom5
# Out:
#        Kommun Population2020  Population2019    change Gender
# 5    Arjeplog           1426          1458.0 -2.194787    Man
# 271     Åsele           1469          1456.0  0.892857    Man
# 29    Dorotea           1327          1356.0 -2.138643    Man
# 271     Åsele           1336          1338.0 -0.149477  Woman
# 5    Arjeplog           1292          1327.0 -2.637528  Woman
# 194   Sorsele           1285          1319.0  -2.57771    Man
# 12   Bjurholm           1233          1249.0 -1.281025    Man
# 29    Dorotea           1171          1195.0 -2.008368  Woman
# 194   Sorsele           1157          1170.0 -1.111111  Woman
# 12   Bjurholm           1154          1159.0 -0.431406  Woman

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1,2, figsize=(16, 4), dpi=120)
titles = ["Top 5 percentual change", "Bottom 5 percentual change"]
data_frames = (top5, bottom5)
x_colums = ["Kommun", "Kommun"]

for i, (data, title) in enumerate(zip(data_frames, titles)):
    sns.barplot(data=data, x=x_colums[i], y="Population2020", ax=axes[i], hue="Gender")
    axes[i].set(title=title)
fig.show()
# Out:
# C:\Users\CYRILLE\AppData\Local\Temp\ipykernel_33252\1139632297.py:12: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
