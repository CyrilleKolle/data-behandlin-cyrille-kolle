# %%
import pandas as pd

df = pd.read_csv('../Data/student-mat-missing-data.csv')
df.head()
# Out:
#    Unnamed: 0 school sex   age address famsize Pstatus  Medu  Fedu     Mjob  \
# 0           0     GP   F  18.0       U     GT3       A     4     4  at_home
# 1           1     GP   F  17.0       U     GT3       T     1     1  at_home
# 2           2     GP   F  15.0       U     LE3       T     1     1  at_home
# 3           3     GP   F  15.0       U     GT3       T     4     2   health
# 4           4     GP   F  16.0       U     GT3       T     3     3    other
#
#    ... famrel freetime goout  Dalc  Walc  health absences  G1  G2  G3
# 0  ...    4.0      3.0   4.0     1     1     3.0      6.0   5   6   6
# 1  ...    5.0      3.0   3.0     1     1     3.0      4.0   5   5   6
# 2  ...    4.0      3.0   2.0     2     3     3.0     10.0   7   8  10
# 3  ...    3.0      2.0   2.0     1     1     5.0      2.0  15  14  15
# 4  ...    4.0      3.0   2.0     1     2     5.0      4.0   6  10  10
#
# [5 rows x 34 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 34 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  395 non-null    int64
#  1   school      395 non-null    object
#  2   sex         395 non-null    object
#  3   age         381 non-null    float64
#  4   address     390 non-null    object
#  5   famsize     395 non-null    object
#  6   Pstatus     395 non-null    object
#  7   Medu        395 non-null    int64
#  8   Fedu        395 non-null    int64
#  9   Mjob        395 non-null    object
#  10  Fjob        395 non-null    object
#  11  reason      395 non-null    object
#  12  guardian    395 non-null    object
#  13  traveltime  395 non-null    int64
#  14  studytime   395 non-null    int64
#  15  failures    395 non-null    int64
#  16  schoolsup   395 non-null    object
#  17  famsup      395 non-null    object
#  18  paid        395 non-null    object
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0         age        Medu        Fedu  traveltime   studytime  \
# count  395.000000  381.000000  395.000000  395.000000  395.000000  395.000000
# mean   197.000000   16.700787    2.749367    2.521519    1.448101    2.035443
# std    114.170924    1.275157    1.094735    1.088201    0.697505    0.839240
# min      0.000000   15.000000    0.000000    0.000000    1.000000    1.000000
# 25%     98.500000   16.000000    2.000000    2.000000    1.000000    1.000000
# 50%    197.000000   17.000000    3.000000    2.000000    1.000000    2.000000
# 75%    295.500000   18.000000    4.000000    3.000000    2.000000    2.000000
# max    394.000000   22.000000    4.000000    4.000000    4.000000    4.000000
#
#          failures      famrel    freetime       goout        Dalc        Walc  \
# count  395.000000  390.000000  379.000000  390.000000  395.000000  395.000000
# mean     0.334177    3.943590    3.237467    3.120513    1.481013    2.291139
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0     0
# school         0
# sex            0
# age           14
# address        5
# famsize        0
# Pstatus        0
# Medu           0
# Fedu           0
# Mjob           0
# Fjob           0
# reason         0
# guardian       0
# traveltime     0
# studytime      0
# failures       0
# schoolsup      0
# famsup         0
# paid           0
# activities     0
# nursery        0
# higher         0
# internet       0
# romantic       0
# famrel         5
# freetime      16
# goout          5
# Dalc           0
# Walc           0
# health         5
# absences       5
# G1             0
# G2             0
# G3             0
# dtype: int64

# %%
df.value_counts()
# Out:
# Unnamed: 0  school  sex  age   address  famsize  Pstatus  Medu  Fedu  Mjob      Fjob      reason      guardian  traveltime  studytime  failures  schoolsup  famsup  paid  activities  nursery  higher  internet  romantic  famrel  freetime  goout  Dalc  Walc  health  absences  G1  G2  G3
# 0           GP      F    18.0  U        GT3      A        4     4     at_home   teacher   course      mother    2           2          0         yes        no      no    no          yes      yes     no        no        4.0     3.0       4.0    1     1     3.0     6.0       5   6   6     1
# 258         GP      M    18.0  U        GT3      T        2     1     other     other     home        mother    1           2          0         no         no      no    yes         yes      yes     yes       no        5.0     2.0       4.0    1     2     4.0     8.0       15  14  14    1
# ...

# %%
df["sex"].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df[df["sex"] == "F"].isnull().sum()
# Out:
# Unnamed: 0     0
# school         0
# sex            0
# age            9
# address        4
# famsize        0
# Pstatus        0
# Medu           0
# Fedu           0
# Mjob           0
# Fjob           0
# reason         0
# guardian       0
# traveltime     0
# studytime      0
# failures       0
# schoolsup      0
# famsup         0
# paid           0
# activities     0
# nursery        0
# higher         0
# internet       0
# romantic       0
# famrel         4
# freetime      10
# goout          4
# Dalc           0
# Walc           0
# health         4
# absences       4
# G1             0
# G2             0
# G3             0
# dtype: int64

# %%
df[df["sex"] == "M"].isnull().sum()
# Out:
# Unnamed: 0    0
# school        0
# sex           0
# age           5
# address       1
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        1
# freetime      6
# goout         1
# Dalc          0
# Walc          0
# health        1
# absences      1
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
df.columns[df.isna().any()].tolist()
# Out:
# ['age', 'address', 'famrel', 'freetime', 'goout', 'health', 'absences']

# %%
from turtle import title
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt


def dataFrame_plotter(data: pd.DataFrame):
    list_missing_columns = df.columns[df.isna().any()].tolist()

    data_frames = []
    missing_val = pd.DataFrame
    for item in list_missing_columns:
        data_frames.append(data[data[item].isnull()])

    age_dataframe = df[df["age"].isnull()]
    print(age_dataframe)

   


dataFrame_plotter(df)
# Out:
#      Unnamed: 0 school sex  age address famsize Pstatus  Medu  Fedu      Mjob  \
# 20           20     GP   M  NaN       U     GT3       T     4     3   teacher
# 71           71     GP   M  NaN       U     GT3       T     4     2     other
# 102         102     GP   M  NaN       U     GT3       T     4     4  services
# 106         106     GP   F  NaN       U     GT3       T     2     2     other
# 121         121     GP   M  NaN       U     GT3       T     2     2  services
# 160         160     GP   M  NaN     NaN     LE3       T     2     1   at_home
# 188         188     GP   F  NaN       U     GT3       A     3     3    health
# 191         191     GP   F  NaN     NaN     GT3       T     1     1   at_home
# 214         214     GP   F  NaN       R     LE3       T     4     4  services
# 270         270     GP   F  NaN       U     GT3       T     3     3     other
# 276         276     GP   F  NaN     NaN     GT3       A     3     2     other
# ...
